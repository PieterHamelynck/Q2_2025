# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('Instemming Huize G (Responses).xlsx')
df.head()
# Out:
#                 Timestamp            Email address  \
# 0 2026-06-08 20:33:25.124    limmied2004@gmail.com
# 1 2026-06-08 21:34:38.940  hugodamhuis@outlook.com
# 2 2026-06-08 21:51:41.996     Liekehorck@gmail.com
# 3 2026-06-08 21:59:18.353    nalcisena26@gmail.com
# 4 2026-06-08 22:19:00.748  i.steenbekkers@imevo.nl
#
#   Hoe noemen je vrienden jou? (voor- en achternaam)  \
# 0                                   Willem Dieleman
# 1                                      Hugo Damhuis
# 2                                       Lieke Horck
# 3                                        Sena Nalci
# 4                  Imke Steenbekkers (bijnaam RoFi)
#
#                                     Hoe oud ben jij?  \
# 0                                                 21
# 1                                                 22
# 2                                                 22
# 3  19 (binnen een maand 20…gecondoleerd mijn jeugd)
# 4                                            22 jaar
#
# ...

# %%
df_filtered = df.loc[:,['Vertel hier wat leuks over jezelf','Fotootjes van jou!']]

for index, row in df_filtered.iterrows():
    print(f"Row {index}: {row['Vertel hier wat leuks over jezelf']}")
    for i in row['Fotootjes van jou!'].split(','):
        print(f"  Foto: {i.strip()}")
# Out:
# Row 0: Ik ben dus Willem, nu nog 21, bijna 22 jaar, en heb vorig jaar mijn bachelor Computer Science afgerond. Ik doe nu een jaar fulltime een Dreamteam bij Team Epoch, wat overigens niet slecht loopt (16.5k euro prijzengeld in 2 weken, gratis reizen naar Zurich en Zuid-Afrika). Volgend jaar ga ik de Master Data Science and AI Technology starten.
#
# Ik hou van koken (Italiaans en Mexicaans <3) en kan met de juiste apparatuur (en groot balkon!) echt fenomenale pizza's maken. Tijdens het koken waardeer ik ten zeerste een opgeruimde keuken en zou ik naar 4 jaar met de hand afwassen een vaatwasser echt aanbidden.
#
# Ik spendeer mijn avonden het liefst met een spel (fysiek of digitaal), of met ouwehoeren op de bank met wat sport, documentaire of film op de achtergrond. Ik kan echt uren lullen over hoe kut de dreamhall eigenlijk is of alles over met wielrennen.
#
# ...
